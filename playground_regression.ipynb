# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
from intESN import intESN
import matplotlib.pyplot as plt

# %%
# dataset
# freq = np.concatenate(([1] * 40, [0.5] * 50, [0.2] * 30, [1] * 30, [0.1] * 50, [0.2] * 20, [1] * 30, [0.5] * 50))
# freq = np.fromfunction(lambda i: 1.0 / i, (300,), dtype=int)


data = np.load('mackey_glass_t17.npy') #  http://minds.jacobs-university.de/mantas/code

train_size = 3000
test_size = 1000
X_train = np.array([np.ones(train_size)])
y_train = np.array([data[:train_size]])

X_test = np.array([np.ones(test_size)])
y_test = np.array([data[train_size:train_size+test_size]])

X_train = np.reshape(X_train, (1, 2000, 1))
y_train = np.reshape(y_train, (1, 2000, 1))

X_test = np.reshape(X_test, (1, 2000, 1))
y_test = np.reshape(y_test, (1, 2000, 1))

# %%
# show data
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(15,5), sharex=True)
ax1.plot(np.arange(len(X_train[0])), X_train[0])
ax2.plot(np.arange(len(X_train[0])), y_train[0])

plt.show()

# %%
# dimensnions
# K: inputs , N: neurons, L: outputs
K = 1
N = 10000
L = 1

# projection !!!
# TODO: refactor me to usea proper HDC framework
sensitivity = 200
levels = np.linspace(-1.0, 1.0, sensitivity)
ref_vectors = np.array([np.random.choice([-1.0, 0.0, 1.0], size=N) for i in range(2)])
# hd_map = np.array([np.random.choice([-1.0, 0.0, 1.0], size=N) for i in range(len(levels) + 1)])

# quantization function
def quantize(value):
#     print(value)
    level = np.digitize(value, levels)
    section = int(level / float(sensitivity) * N)
    
    return np.append(ref_vectors[0][:section], ref_vectors[1][section:])
#     return hd_map[np.digitize(value, levels)]

model = intESN(N, K, L, quantize, q_output=quantize, output_fb=True, clip=13)

# %%
# train model
model.fit(X_train, y_train, discard=0.05)
# Out:
# 0.305748984409

# %%
# test
pred = model.predict(X_test, y_test, reset=False)
# Out:
# (1, 1000, 1)
# 0.19884127616

# %%
# display results
# red: predictions
# grey: ground truth

plt.figure(figsize=(18,2))
plt.plot(np.arange(2000, 4000), pred[0], 'r')
plt.plot(np.arange(4000), data[:4000], 'k', alpha=0.5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-be5bc8758b0c> in <module>()
#       4
#       5 plt.figure(figsize=(18,2))
# ----> 6 plt.plot(np.arange(2000, 4000), pred[0], 'r')
#       7 plt.plot(np.arange(4000), data[:4000], 'k', alpha=0.5)
#       8
#
# C:\Users\Mansour\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# C:\Users\Mansour\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Users\Mansour\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# C:\Users\Mansour\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# C:\Users\Mansour\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# C:\Users\Mansour\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     242         if x.shape[0] != y.shape[0]:
#     243             raise ValueError("x and y must have same first dimension, but "
# --> 244                              "have shapes {} and {}".format(x.shape, y.shape))
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (2000,) and (1000, 1)
